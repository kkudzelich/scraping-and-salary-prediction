# %%
import pandas as pd
import numpy as np
from tqdm import tqdm
from matplotlib import pyplot as plt
import matplotlib as mpl
import seaborn as sns
from sklearn.preprocessing import MinMaxScaler
import re
import csv

import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR, ReduceLROnPlateau

# %%
df = pd.read_csv('final_df.csv')

# %%
# Divide the column into 2 columns: rate_type and estimator
df[['rate_type', 'estimator']] = df['per_hour_or_year'].str.extract(r'/(yr|hr) \((Employer|Glassdoor) est.\)')
# Drop initial column
df = df.drop(columns=['per_hour_or_year'])
df
# Out:
#                   employer  employer_rating                   sector  \
# 0                  Parsons              4.0   Information Technology
# 1                   TriNet              3.7  Management & Consulting
# 2                 Cotiviti              3.7   Information Technology
# 3     Alliant Credit Union              3.3       Financial Services
# 4         NextDeavor, Inc.              4.5                      NaN
# ...                    ...              ...                      ...
# 1866                 Plaid              4.1   Information Technology
# 1867                 Apple              4.2   Information Technology
# 1868               Madhive              3.7   Information Technology
# 1869     TRICORPS SECURITY              3.4  Management & Consulting
# 1870            Worldforce              3.5                      NaN
#
#                                      industry  employer_founded  \
# 0     Information Technology Support Services            1944.0
# 1                         Business Consulting            1988.0
# 2     Information Technology Support Services            1979.0
# 3                           Banking & Lending            1935.0
# 4                                         NaN               NaN
# ...                                       ...               ...
# 1866  Enterprise Software & Network Solutions            2012.0
# 1867            Computer Hardware Development            1976.0
# 1868  Enterprise Software & Network Solutions            2017.0
# 1869                    Security & Protective               NaN
# 1870                                      NaN               NaN
#
#                       employer_revenue  \
# 0               $1 to $5 billion (USD)
# 1               $1 to $5 billion (USD)
# 2     $500 million to $1 billion (USD)
# 3              $5 to $25 million (USD)
# 4             Unknown / Non-Applicable
# ...                                ...
# 1866          Unknown / Non-Applicable
# 1867                $10+ billion (USD)
# 1868          Unknown / Non-Applicable
# 1869          Unknown / Non-Applicable
# 1870                               NaN
#
#                                               job_title           location  \
# 0                                        Data Scientist             Remote
# 1                                        Data Scientist             Remote
# 2                                      Data Scientist I             Remote
# 3                               Data Scientist - Hybrid        Chicago, IL
# 4                      Data Scientist, Product Insights  San Francisco, CA
# ...                                                 ...                ...
# 1866     Experienced Machine Learning Engineer - Credit  San Francisco, CA
# 1867  AIML - Senior Data Infrastructure Software Eng...      Cupertino, CA
# 1868              Engineering Manager, Machine Learning             Remote
# 1869  Artificial Intelligence Implementation Specialist  Oklahoma City, OK
# 1870                             Product Manager for AI             Remote
#
#      min_salary max_salary average_base_salary rate_type  estimator
# 0          100K       176K            $138,050        yr   Employer
# 1           76K       182K            $129,200        yr   Employer
# 2           93K       109K            $101,000        yr   Employer
# 3          115K       142K            $127,549        yr  Glassdoor
# 4         90.00     105.63              $97.81        hr   Employer
# ...         ...        ...                 ...       ...        ...
# 1866       226K       319K            $272,520        yr   Employer
# 1867       200K       364K            $281,950        yr   Employer
# 1868       240K       300K            $270,000        yr   Employer
# 1869        50K        50K             $50,000        yr   Employer
# 1870        40K       130K             $85,000        yr   Employer
#
# [1871 rows x 13 columns]

# %%
# Check how much values with hour rate
df[df['rate_type'] == 'hr']
# Out:
#                           employer  employer_rating                  sector  \
# 4                 NextDeavor, Inc.              4.5                     NaN
# 9                  Agile Tech Labs              5.0                     NaN
# 26                Meridiansoft INC              4.1                     NaN
# 39            Meritor ITconsulting              4.8                     NaN
# 54                        Data Inc              3.9  Information Technology
# ...                            ...              ...                     ...
# 1557  Pinnacle Technical Resources              3.7                     NaN
# 1558      Capitaltechsolutions Inc              3.2                     NaN
# 1574          Ehub Global solution              3.5                     NaN
# 1589     Zonestra Technologies llc              3.0                     NaN
# 1598                Cybotic System              3.6                     NaN
#
#                                      industry  employer_founded  \
# 4                                         NaN               NaN
# 9                                         NaN               NaN
# 26                                        NaN               NaN
# 39                                        NaN               NaN
# 54    Information Technology Support Services            1983.0
# ...                                       ...               ...
# 1557                                      NaN               NaN
# 1558                                      NaN               NaN
# 1574                                      NaN               NaN
# 1589                                      NaN               NaN
# 1598                                      NaN               NaN
#
#                employer_revenue  \
# 4      Unknown / Non-Applicable
# 9      Unknown / Non-Applicable
# 26                          NaN
# 39                          NaN
# 54    $25 to $100 million (USD)
# ...                         ...
# 1557     $1 to $5 million (USD)
# 1558   Unknown / Non-Applicable
# 1574   Unknown / Non-Applicable
# 1589                        NaN
# 1598   Unknown / Non-Applicable
#
#                                               job_title           location  \
# 4                      Data Scientist, Product Insights  San Francisco, CA
# 9                                      Sr. Data Analyst             Remote
# 26                         DATA Science/ Data Scientist        Phoenix, AZ
# 39                                       AI/ML Engineer             Remote
# 54                                  Senior Data Analyst       New York, NY
# ...                                                 ...                ...
# 1557                        AI Business Systems Analyst             Alaska
# 1558  5+ Years in Research/Data Analyst Senior- Atla...        Atlanta, GA
# 1574                                     Data Scientist         Austin, TX
# 1589  AI Ops Engineer/Software Engineer (AI, Python,...         Moline, IL
# 1598  New W2 Contract Job Role: Principal Engineer (...      Charlotte, NC
#
#      min_salary max_salary average_base_salary rate_type estimator
# 4         90.00     105.63              $97.81        hr  Employer
# 9         55.00      60.00              $57.50        hr  Employer
# 26        30.00      45.22              $37.61        hr  Employer
# 39        60.00      60.00              $60.00        hr  Employer
# 54        60.00      70.00              $65.00        hr  Employer
# ...         ...        ...                 ...       ...       ...
# 1557      40.00      45.00              $42.50        hr  Employer
# 1558      45.00      50.00              $47.50        hr  Employer
# 1574      28.96      55.28              $42.12        hr  Employer
# 1589      40.00      45.80              $42.90        hr  Employer
# 1598      80.00     100.00              $90.00        hr  Employer
#
# [110 rows x 13 columns]

# %%
# Function to convert min_salary and max_salary into in a single format and with an annual rate
def clean_and_convert(value, rate_type):
    if rate_type == 'yr':
        value = value.replace('K', '')
        return float(value) * 1000
    elif rate_type == 'hr':
        return float(value) * 160 * 12

# %%
# Apply the function above
for col in ['min_salary', 'max_salary']:
    df[col] = df.apply(lambda row: clean_and_convert(row[col], row['rate_type']), axis=1)

# %%
# Function to convert average_base_salary into in a single format and with an annual rate
def clean_and_convert_average_base(value, rate_type):
    if rate_type == 'yr':
        value = value.replace('$', '').replace(',', '')
        return float(value)
    elif rate_type == 'hr':
        value = value.replace('$', '')
        return float(value) * 160 * 12

# %%
# Apply the function above
df['average_base_salary'] = df.apply(lambda row: clean_and_convert_average_base(row['average_base_salary'], row['rate_type']), axis=1)

# %%
# Delete rate type, because all rates are per year now
df = df.drop(columns=['rate_type'])

# %%
# Save df to csv
df.to_csv('transformed_df.csv', index=False)

# %%
df = pd.read_csv('transformed_df.csv')
df
# Out:
#                   employer  employer_rating                   sector  \
# 0                  Parsons              4.0   Information Technology
# 1                   TriNet              3.7  Management & Consulting
# 2                 Cotiviti              3.7   Information Technology
# 3     Alliant Credit Union              3.3       Financial Services
# 4         NextDeavor, Inc.              4.5                      NaN
# ...                    ...              ...                      ...
# 1866                 Plaid              4.1   Information Technology
# 1867                 Apple              4.2   Information Technology
# 1868               Madhive              3.7   Information Technology
# 1869     TRICORPS SECURITY              3.4  Management & Consulting
# 1870            Worldforce              3.5                      NaN
#
#                                      industry  employer_founded  \
# 0     Information Technology Support Services            1944.0
# 1                         Business Consulting            1988.0
# 2     Information Technology Support Services            1979.0
# 3                           Banking & Lending            1935.0
# 4                                         NaN               NaN
# ...                                       ...               ...
# 1866  Enterprise Software & Network Solutions            2012.0
# 1867            Computer Hardware Development            1976.0
# 1868  Enterprise Software & Network Solutions            2017.0
# 1869                    Security & Protective               NaN
# 1870                                      NaN               NaN
#
#                       employer_revenue  \
# 0               $1 to $5 billion (USD)
# 1               $1 to $5 billion (USD)
# 2     $500 million to $1 billion (USD)
# 3              $5 to $25 million (USD)
# 4             Unknown / Non-Applicable
# ...                                ...
# 1866          Unknown / Non-Applicable
# 1867                $10+ billion (USD)
# 1868          Unknown / Non-Applicable
# 1869          Unknown / Non-Applicable
# 1870                               NaN
#
#                                               job_title           location  \
# 0                                        Data Scientist             Remote
# 1                                        Data Scientist             Remote
# 2                                      Data Scientist I             Remote
# 3                               Data Scientist - Hybrid        Chicago, IL
# 4                      Data Scientist, Product Insights  San Francisco, CA
# ...                                                 ...                ...
# 1866     Experienced Machine Learning Engineer - Credit  San Francisco, CA
# 1867  AIML - Senior Data Infrastructure Software Eng...      Cupertino, CA
# 1868              Engineering Manager, Machine Learning             Remote
# 1869  Artificial Intelligence Implementation Specialist  Oklahoma City, OK
# 1870                             Product Manager for AI             Remote
#
#       min_salary  max_salary  average_base_salary  estimator
# 0       100000.0    176000.0             138050.0   Employer
# 1        76000.0    182000.0             129200.0   Employer
# 2        93000.0    109000.0             101000.0   Employer
# 3       115000.0    142000.0             127549.0  Glassdoor
# 4       172800.0    202809.6             187795.2   Employer
# ...          ...         ...                  ...        ...
# 1866    226000.0    319000.0             272520.0   Employer
# 1867    200000.0    364000.0             281950.0   Employer
# 1868    240000.0    300000.0             270000.0   Employer
# 1869     50000.0     50000.0              50000.0   Employer
# 1870     40000.0    130000.0              85000.0   Employer
#
# [1871 rows x 12 columns]
